# %% [markdown]
# # Changes made by Team
# - `en_core_med7_lg` was pip installed
#   - `!pip install https://huggingface.co/kormilitzin/en_core_med7_lg/resolve/main/en_core_med7_lg-any-py3-none-any.whl`
# -  added timer function to have an idea of elapsed time

# %%
a/!pip install https://huggingface.co/kormilitzin/en_core_med7_lg/resolve/main/en_core_med7_lg-any-py3-none-any.whl
# Out:
# Collecting en-core-med7-lg==any
#   Downloading https://huggingface.co/kormilitzin/en_core_med7_lg/resolve/main/en_core_med7_lg-any-py3-none-any.whl (607.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.4/607.4 MB 13.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.2 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from en-core-med7-lg==any) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (1.10.15)
# Requirement already satisfied: jinja2 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (3.1.3)
# Requirement already satisfied: setuptools in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayushghosh/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.5.0,>=3.4.2->en-core-med7-lg==any) (2.1.3)

# %%
import pandas as pd
import spacy

med7 = spacy.load("en_core_med7_lg")

# %%
preprocessed_df = pd.read_pickle("data/preprocessed_notes.p")

# %%
preprocessed_df['ner'] = None

# %%
count = 0
preprocessed_index = {}
for i in preprocessed_df.itertuples():
    
    if count % 1000 == 0:
        print(count)

    count += 1
    ind = i.Index
    text = i.preprocessed_text
    
    all_pred = []
    for each_sent in text:
        try:
            doc = med7(each_sent)
            result = ([(ent.text, ent.label_) for ent in doc.ents])
            if len(result) == 0: continue
            all_pred.append(result)
        except:
            print("error..")
            continue
    preprocessed_df.at[ind, 'ner'] = all_pred
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000

# %%
pd.to_pickle(preprocessed_df, "data/ner_df.p")
